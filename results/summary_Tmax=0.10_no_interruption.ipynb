# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#Plot all columns of df_PPO_R2_p1 with respect to alpha in one plot:
def multi_plot_scatter_with_lines(df, 
    legend_labels=['Final tax rate', 'Mean tax rate', 'Median tax rate', 'Std tax rate', 'Max tax rate', 'Min tax rate'], 
    colors=['blue', 'red', 'green', 'orange', 'black', 'purple'], 
    title='Tax rates for percentile vs Alpha'):
    """
    Plots scatter plots with connecting lines for specified columns against a common x-axis.

    Parameters:
    - df: pandas DataFrame containing the data.
    - title: string, title of the plot.
    """
    # Ensure legend_labels and colors have the same length
    if len(legend_labels) != len(colors):
        raise ValueError("legend_labels and colors must have the same length.")
    
    # Sorting the DataFrame based on 'alpha' to ensure lines are plotted correctly
    df_sorted = df.sort_values(by='alpha')

    y_labels = df.columns[1:]

    # Setting up the plot
    plt.figure(figsize=(5, 3))

    # Plotting each column against 'alpha' with custom legend labels
    for y_label, legend_label, color in zip(y_labels, legend_labels, colors):
        plt.scatter(df_sorted['alpha'], df_sorted[y_label], label=legend_label, color=color, alpha=0.5)
        plt.plot(df_sorted['alpha'], df_sorted[y_label], color=color, linestyle='--', alpha=0.5)

    # Adding legend, grid, labels, and title
    plt.legend()
    plt.grid(True)
    plt.xlabel('Alpha')
    plt.ylabel('Values')
    plt.title(title)

    # Setting the xlim and ylim based on the min and max values of 'alpha' and y_labels
    x_min, x_max = df_sorted['alpha'].min(), df_sorted['alpha'].max()
    y_min = min(df_sorted[label].min() for label in y_labels)
    y_max = max(df_sorted[label].max() for label in y_labels)
    plt.xlim(x_min - 0.05, x_max + 0.05) # Slightly wider range for clarity
    plt.ylim(y_min - 0.05, y_max + 0.05) # Slightly wider range for clarity

    # Display the plot
    plt.show()

# %%
def plot_scatter_with_lines(df, legend_labels=['T_max', 'T_esp', 'T_scale'], colors=['blue', 'red', 'green'], title='T_max, T_esp, T_scale vs Alpha'):
    """
    Plots scatter plots with connecting lines for specified columns against a common x-axis.

    Parameters:
    - df: pandas DataFrame containing the data.
    - legend_labels: list of strings, labels for the legend corresponding to the columns to plot.
    - colors: list of strings, colors for each plot.
    - title: string, title of the plot.
    """
    # Ensure legend_labels and colors have the same length
    if len(legend_labels) != len(colors):
        raise ValueError("legend_labels and colors must have the same length.")
    
    # Fixed column names
    y_labels = ['T_max', 'T_esp', 'T_scale']

    # Sorting the DataFrame based on 'alpha' to ensure lines are plotted correctly
    df_sorted = df.sort_values(by='alpha')

    # Setting up the plot
    plt.figure(figsize=(5, 3))

    # Plotting each column against 'alpha' with custom legend labels
    for y_label, legend_label, color in zip(y_labels, legend_labels, colors):
        plt.scatter(df_sorted['alpha'], df_sorted[y_label], label=legend_label, color=color, alpha=0.5)
        plt.plot(df_sorted['alpha'], df_sorted[y_label], color=color, linestyle='--', alpha=0.5)

    # Adding legend, grid, labels, and title
    plt.legend()
    plt.grid(True)
    plt.xlabel('Alpha')
    plt.ylabel('Values')
    plt.title(title)

    # Setting the xlim and ylim based on the min and max values of 'alpha' and y_labels
    x_min, x_max = df_sorted['alpha'].min(), df_sorted['alpha'].max()
    #y_min = min(df_sorted[label].min() for label in y_labels)
    #y_max = max(df_sorted[label].max() for label in y_labels)
    plt.xlim(x_min - 0.05, x_max + 0.05) # Slightly wider range for clarity
    #plt.ylim(y_min - 0.05, y_max + 0.05) # Slightly wider range for clarity

    # Display the plot
    plt.show()

# %% [markdown]
# # R2

# %% [markdown]
# ## PPO

# %% [markdown]
# ### T_max, T_esp, T_scale vs alpha

# %%
# Define the path to the file
file_path_PPO_R2_final = 'results/tax_param_vs_alpha/PPO/R2_final_tax_vs_alpha.csv'
file_path_PPO_R2_mean = 'results/tax_param_vs_alpha/PPO/R2_mean_tax_vs_alpha.csv'
file_path_PPO_R2_median = 'results/tax_param_vs_alpha/PPO/R2_median_tax_vs_alpha.csv'
file_path_PPO_R2_max = 'results/tax_param_vs_alpha/PPO/R2_max_tax_vs_alpha.csv'
file_path_PPO_R2_min = 'results/tax_param_vs_alpha/PPO/R2_min_tax_vs_alpha.csv'
file_path_PPO_R2_std = 'results/tax_param_vs_alpha/PPO/R2_std_tax_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_PPO_R2_final = pd.read_csv(file_path_PPO_R2_final)
df_PPO_R2_mean = pd.read_csv(file_path_PPO_R2_mean)
df_PPO_R2_median = pd.read_csv(file_path_PPO_R2_median)
df_PPO_R2_max = pd.read_csv(file_path_PPO_R2_max)
df_PPO_R2_min = pd.read_csv(file_path_PPO_R2_min)
df_PPO_R2_std = pd.read_csv(file_path_PPO_R2_std)

# Display the first few rows of the DataFrame
#print(df_PPO_R2_final.head())

# %%
legend_labels = ['Final T_max', 'Final T_esp', 'Final T_scale']
plot_scatter_with_lines(df_PPO_R2_final, legend_labels=legend_labels, title='Final T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Mean T_max', 'Mean T_esp', 'Mean T_scale']
plot_scatter_with_lines(df_PPO_R2_mean, legend_labels=legend_labels, title='Mean T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Median T_max', 'Median T_esp', 'Median T_scale']
plot_scatter_with_lines(df_PPO_R2_median, legend_labels=legend_labels, title='Median T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Max T_max', 'Max T_esp', 'Max T_scale']
plot_scatter_with_lines(df_PPO_R2_max, legend_labels=legend_labels, title='Max T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Min T_max', 'Min T_esp', 'Min T_scale']
plot_scatter_with_lines(df_PPO_R2_min, legend_labels=legend_labels, title='Min T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Std T_max', 'Std T_esp', 'Std T_scale']
plot_scatter_with_lines(df_PPO_R2_std, legend_labels=legend_labels, title='Std T_max, T_esp, T_scale vs Alpha')

# %% [markdown]
# ### Percentile Tax Rates vs alpha

# %%
# Define the path to the file
file_path_PPO_R2_p1 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_1th_percentile_vs_alpha.csv'
file_path_PPO_R2_p10 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_10th_percentile_vs_alpha.csv'
file_path_PPO_R2_p25 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_25th_percentile_vs_alpha.csv'
file_path_PPO_R2_p50 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_50th_percentile_vs_alpha.csv'
file_path_PPO_R2_p75 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_75th_percentile_vs_alpha.csv'
file_path_PPO_R2_p90 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_90th_percentile_vs_alpha.csv'
file_path_PPO_R2_p95 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_95th_percentile_vs_alpha.csv'
file_path_PPO_R2_p99 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_99th_percentile_vs_alpha.csv'
file_path_PPO_R2_p999 = 'results/tax_param_vs_alpha/PPO/R2_final_tax_99.9th_percentile_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_PPO_R2_p1 = pd.read_csv(file_path_PPO_R2_p1)
df_PPO_R2_p10 = pd.read_csv(file_path_PPO_R2_p10)
df_PPO_R2_p25 = pd.read_csv(file_path_PPO_R2_p25)
df_PPO_R2_p50 = pd.read_csv(file_path_PPO_R2_p50)
df_PPO_R2_p75 = pd.read_csv(file_path_PPO_R2_p75)
df_PPO_R2_p90 = pd.read_csv(file_path_PPO_R2_p90)
df_PPO_R2_p95 = pd.read_csv(file_path_PPO_R2_p95)
df_PPO_R2_p99 = pd.read_csv(file_path_PPO_R2_p99)
df_PPO_R2_p999 = pd.read_csv(file_path_PPO_R2_p999)

# %%
# Plot all columns of df_PPO_R2_p1 with respect to alpha in one plot:
multi_plot_scatter_with_lines(df_PPO_R2_p1, title='Tax rates for percentile 1 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p50, title='Tax rates for percentile 50 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p10, title='Tax rates for percentile 10 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p25, title='Tax rates for percentile 25 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p75, title='Tax rates for percentile 75 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p90, title='Tax rates for percentile 90 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p95, title='Tax rates for percentile 95 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p99, title='Tax rates for percentile 99 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R2_p999, title='Tax rates for percentile 99.9 vs Alpha')

# %% [markdown]
# ## SAC

# %% [markdown]
# ### T_max, T_esp, T_scale vs alpha

# %%
# Define the path to the file
file_path_SAC_R2_final = 'results/tax_param_vs_alpha/SAC/R2_final_tax_vs_alpha.csv'
file_path_SAC_R2_mean = 'results/tax_param_vs_alpha/SAC/R2_mean_tax_vs_alpha.csv'
file_path_SAC_R2_median = 'results/tax_param_vs_alpha/SAC/R2_median_tax_vs_alpha.csv'
file_path_SAC_R2_max = 'results/tax_param_vs_alpha/SAC/R2_max_tax_vs_alpha.csv'
file_path_SAC_R2_min = 'results/tax_param_vs_alpha/SAC/R2_min_tax_vs_alpha.csv'
file_path_SAC_R2_std = 'results/tax_param_vs_alpha/SAC/R2_std_tax_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_SAC_R2_final = pd.read_csv(file_path_SAC_R2_final)
df_SAC_R2_mean = pd.read_csv(file_path_SAC_R2_mean)
df_SAC_R2_median = pd.read_csv(file_path_SAC_R2_median)
df_SAC_R2_max = pd.read_csv(file_path_SAC_R2_max)
df_SAC_R2_min = pd.read_csv(file_path_SAC_R2_min)
df_SAC_R2_std = pd.read_csv(file_path_SAC_R2_std)

# %%
legend_labels = ['Final T_max', 'Final T_esp', 'Final T_scale']
plot_scatter_with_lines(df_SAC_R2_final, legend_labels=legend_labels, title='Final T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Mean T_max', 'Mean T_esp', 'Mean T_scale']
plot_scatter_with_lines(df_SAC_R2_mean, legend_labels=legend_labels, title='Mean T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Median T_max', 'Median T_esp', 'Median T_scale']
plot_scatter_with_lines(df_SAC_R2_median, legend_labels=legend_labels, title='Median T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Max T_max', 'Max T_esp', 'Max T_scale']
plot_scatter_with_lines(df_SAC_R2_max, legend_labels=legend_labels, title='Max T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Min T_max', 'Min T_esp', 'Min T_scale']
plot_scatter_with_lines(df_SAC_R2_min, legend_labels=legend_labels, title='Min T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Std T_max', 'Std T_esp', 'Std T_scale']
plot_scatter_with_lines(df_SAC_R2_std, legend_labels=legend_labels, title='Std T_max, T_esp, T_scale vs Alpha')

# %% [markdown]
# ### Percentile Tax Rates vs alpha

# %%
# Define the path to the file
file_path_SAC_R2_p1 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_1th_percentile_vs_alpha.csv'
file_path_SAC_R2_p10 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_10th_percentile_vs_alpha.csv'
file_path_SAC_R2_p25 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_25th_percentile_vs_alpha.csv'
file_path_SAC_R2_p50 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_50th_percentile_vs_alpha.csv'
file_path_SAC_R2_p75 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_75th_percentile_vs_alpha.csv'
file_path_SAC_R2_p90 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_90th_percentile_vs_alpha.csv'
file_path_SAC_R2_p95 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_95th_percentile_vs_alpha.csv'
file_path_SAC_R2_p99 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_99th_percentile_vs_alpha.csv'
file_path_SAC_R2_p999 = 'results/tax_param_vs_alpha/SAC/R2_final_tax_99.9th_percentile_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_SAC_R2_p1 = pd.read_csv(file_path_SAC_R2_p1)
df_SAC_R2_p10 = pd.read_csv(file_path_SAC_R2_p10)
df_SAC_R2_p25 = pd.read_csv(file_path_SAC_R2_p25)
df_SAC_R2_p50 = pd.read_csv(file_path_SAC_R2_p50)
df_SAC_R2_p75 = pd.read_csv(file_path_SAC_R2_p75)
df_SAC_R2_p90 = pd.read_csv(file_path_SAC_R2_p90)
df_SAC_R2_p95 = pd.read_csv(file_path_SAC_R2_p95)
df_SAC_R2_p99 = pd.read_csv(file_path_SAC_R2_p99)
df_SAC_R2_p999 = pd.read_csv(file_path_SAC_R2_p999)

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p1, title='Tax rates for percentile 1 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p10, title='Tax rates for percentile 10 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p25, title='Tax rates for percentile 25 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p50, title='Tax rates for percentile 50 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p75, title='Tax rates for percentile 75 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p90, title='Tax rates for percentile 90 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p95, title='Tax rates for percentile 95 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p99, title='Tax rates for percentile 99 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R2_p999, title='Tax rates for percentile 99.9 vs Alpha')

# %% [markdown]
# # R1

# %% [markdown]
# ## PPO

# %% [markdown]
# ### T_max, T_esp, T_scale vs alpha

# %%
file_path_PPO_R1_final = 'results/tax_param_vs_alpha/PPO/R1_final_tax_vs_alpha.csv'
file_path_PPO_R1_mean = 'results/tax_param_vs_alpha/PPO/R1_mean_tax_vs_alpha.csv'
file_path_PPO_R1_median = 'results/tax_param_vs_alpha/PPO/R1_median_tax_vs_alpha.csv'
file_path_PPO_R1_max = 'results/tax_param_vs_alpha/PPO/R1_max_tax_vs_alpha.csv'
file_path_PPO_R1_min = 'results/tax_param_vs_alpha/PPO/R1_min_tax_vs_alpha.csv'
file_path_PPO_R1_std = 'results/tax_param_vs_alpha/PPO/R1_std_tax_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_PPO_R1_final = pd.read_csv(file_path_PPO_R1_final)
df_PPO_R1_mean = pd.read_csv(file_path_PPO_R1_mean)
df_PPO_R1_median = pd.read_csv(file_path_PPO_R1_median)
df_PPO_R1_max = pd.read_csv(file_path_PPO_R1_max)
df_PPO_R1_min = pd.read_csv(file_path_PPO_R1_min)
df_PPO_R1_std = pd.read_csv(file_path_PPO_R1_std)

# %%
legend_labels = ['Final T_max', 'Final T_esp', 'Final T_scale']
plot_scatter_with_lines(df_PPO_R1_final, legend_labels=legend_labels, title='Final T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Mean T_max', 'Mean T_esp', 'Mean T_scale']
plot_scatter_with_lines(df_PPO_R1_mean, legend_labels=legend_labels, title='Mean T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Median T_max', 'Median T_esp', 'Median T_scale']
plot_scatter_with_lines(df_PPO_R1_median, legend_labels=legend_labels, title='Median T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Max T_max', 'Max T_esp', 'Max T_scale']
plot_scatter_with_lines(df_PPO_R1_max, legend_labels=legend_labels, title='Max T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Min T_max', 'Min T_esp', 'Min T_scale']
plot_scatter_with_lines(df_PPO_R1_min, legend_labels=legend_labels, title='Min T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Std T_max', 'Std T_esp', 'Std T_scale']
plot_scatter_with_lines(df_PPO_R1_std, legend_labels=legend_labels, title='Std T_max, T_esp, T_scale vs Alpha')

# %% [markdown]
# ### Percentile Tax Rates vs alpha

# %%
# Define the path to the file
file_path_PPO_R1_p1 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_1th_percentile_vs_alpha.csv'
file_path_PPO_R1_p10 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_10th_percentile_vs_alpha.csv'
file_path_PPO_R1_p25 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_25th_percentile_vs_alpha.csv'
file_path_PPO_R1_p50 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_50th_percentile_vs_alpha.csv'
file_path_PPO_R1_p75 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_75th_percentile_vs_alpha.csv'
file_path_PPO_R1_p90 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_90th_percentile_vs_alpha.csv'
file_path_PPO_R1_p95 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_95th_percentile_vs_alpha.csv'
file_path_PPO_R1_p99 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_99th_percentile_vs_alpha.csv'
file_path_PPO_R1_p999 = 'results/tax_param_vs_alpha/PPO/R1_final_tax_99.9th_percentile_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_PPO_R1_p1 = pd.read_csv(file_path_PPO_R1_p1)
df_PPO_R1_p10 = pd.read_csv(file_path_PPO_R1_p10)
df_PPO_R1_p25 = pd.read_csv(file_path_PPO_R1_p25)
df_PPO_R1_p50 = pd.read_csv(file_path_PPO_R1_p50)
df_PPO_R1_p75 = pd.read_csv(file_path_PPO_R1_p75)
df_PPO_R1_p90 = pd.read_csv(file_path_PPO_R1_p90)
df_PPO_R1_p95 = pd.read_csv(file_path_PPO_R1_p95)
df_PPO_R1_p99 = pd.read_csv(file_path_PPO_R1_p99)
df_PPO_R1_p999 = pd.read_csv(file_path_PPO_R1_p999)

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p1, title='Tax rates for percentile 1 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p10, title='Tax rates for percentile 10 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p25, title='Tax rates for percentile 25 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p50, title='Tax rates for percentile 50 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p75, title='Tax rates for percentile 75 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p90, title='Tax rates for percentile 90 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p95, title='Tax rates for percentile 95 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p99, title='Tax rates for percentile 99 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_PPO_R1_p999, title='Tax rates for percentile 99.9 vs Alpha')

# %% [markdown]
# ## SAC

# %% [markdown]
# ### T_max, T_esp, T_scale vs alpha

# %%
file_path_SAC_R1_final = 'results/tax_param_vs_alpha/SAC/R1_final_tax_vs_alpha.csv'
file_path_SAC_R1_mean = 'results/tax_param_vs_alpha/SAC/R1_mean_tax_vs_alpha.csv'
file_path_SAC_R1_median = 'results/tax_param_vs_alpha/SAC/R1_median_tax_vs_alpha.csv'
file_path_SAC_R1_max = 'results/tax_param_vs_alpha/SAC/R1_max_tax_vs_alpha.csv'
file_path_SAC_R1_min = 'results/tax_param_vs_alpha/SAC/R1_min_tax_vs_alpha.csv'
file_path_SAC_R1_std = 'results/tax_param_vs_alpha/SAC/R1_std_tax_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_SAC_R1_final = pd.read_csv(file_path_SAC_R1_final)
df_SAC_R1_mean = pd.read_csv(file_path_SAC_R1_mean)
df_SAC_R1_median = pd.read_csv(file_path_SAC_R1_median)
df_SAC_R1_max = pd.read_csv(file_path_SAC_R1_max)
df_SAC_R1_min = pd.read_csv(file_path_SAC_R1_min)
df_SAC_R1_std = pd.read_csv(file_path_SAC_R1_std)

# %%
legend_labels = ['Final T_max', 'Final T_esp', 'Final T_scale']
plot_scatter_with_lines(df_SAC_R1_final, legend_labels=legend_labels, title='Final T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Mean T_max', 'Mean T_esp', 'Mean T_scale']
plot_scatter_with_lines(df_SAC_R1_mean, legend_labels=legend_labels, title='Mean T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Median T_max', 'Median T_esp', 'Median T_scale']
plot_scatter_with_lines(df_SAC_R1_median, legend_labels=legend_labels, title='Median T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Max T_max', 'Max T_esp', 'Max T_scale']
plot_scatter_with_lines(df_SAC_R1_max, legend_labels=legend_labels, title='Max T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Min T_max', 'Min T_esp', 'Min T_scale']
plot_scatter_with_lines(df_SAC_R1_min, legend_labels=legend_labels, title='Min T_max, T_esp, T_scale vs Alpha')

# %%
legend_labels = ['Std T_max', 'Std T_esp', 'Std T_scale']
plot_scatter_with_lines(df_SAC_R1_std, legend_labels=legend_labels, title='Std T_max, T_esp, T_scale vs Alpha')

# %% [markdown]
# ### Percentile Tax Rates vs alpha

# %%
# Define the path to the file
file_path_SAC_R1_p1 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_1th_percentile_vs_alpha.csv'
file_path_SAC_R1_p10 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_10th_percentile_vs_alpha.csv'
file_path_SAC_R1_p25 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_25th_percentile_vs_alpha.csv'
file_path_SAC_R1_p50 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_50th_percentile_vs_alpha.csv'
file_path_SAC_R1_p75 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_75th_percentile_vs_alpha.csv'
file_path_SAC_R1_p90 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_90th_percentile_vs_alpha.csv'
file_path_SAC_R1_p95 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_95th_percentile_vs_alpha.csv'
file_path_SAC_R1_p99 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_99th_percentile_vs_alpha.csv'
file_path_SAC_R1_p999 = 'results/tax_param_vs_alpha/SAC/R1_final_tax_99.9th_percentile_vs_alpha.csv'

# Load the CSV file into a DataFrame
df_SAC_R1_p1 = pd.read_csv(file_path_SAC_R1_p1)
df_SAC_R1_p10 = pd.read_csv(file_path_SAC_R1_p10)
df_SAC_R1_p25 = pd.read_csv(file_path_SAC_R1_p25)
df_SAC_R1_p50 = pd.read_csv(file_path_SAC_R1_p50)
df_SAC_R1_p75 = pd.read_csv(file_path_SAC_R1_p75)
df_SAC_R1_p90 = pd.read_csv(file_path_SAC_R1_p90)
df_SAC_R1_p95 = pd.read_csv(file_path_SAC_R1_p95)
df_SAC_R1_p99 = pd.read_csv(file_path_SAC_R1_p99)
df_SAC_R1_p999 = pd.read_csv(file_path_SAC_R1_p999)

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p1, title='Tax rates for percentile 1 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p10, title='Tax rates for percentile 10 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p25, title='Tax rates for percentile 25 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p50, title='Tax rates for percentile 50 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p75, title='Tax rates for percentile 75 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p90, title='Tax rates for percentile 90 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p95, title='Tax rates for percentile 95 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p99, title='Tax rates for percentile 99 vs Alpha')

# %%
multi_plot_scatter_with_lines(df_SAC_R1_p999, title='Tax rates for percentile 99.9 vs Alpha')
